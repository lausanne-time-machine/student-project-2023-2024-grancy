# %%
JOB_CAT_ABRV = {
                'chef': ['chef'],
                'policier': ['ag. de olice', 'police', 'polic'],
                'électricien': ['électric', 'élec'],
                'architecte': ['arch'],
                'professeur': ['prof', "prof d'école"],
                'couturier': ['cout'],
                'tapissier': ['tapiss', 'tap'],
                'agriculteur': ['agri', 'agricult'],
                'directeur': ['d.', 'dir'],
                'ménagère': ['ménag', 'men', 'mén'],
                'serrurier': ['serrur', 'serrar'],
                'commerçant': ['comm', 'commerc', 'commercant'],
                'maçon': ['macon'],
                'évangéliste': ['évang', 'évan'],
                'comptable': ['compt'],
                'veuve': ['vve', 'veuv'],
                'négociant': ['nég', 'négo'],
                'conducteur CFF': ['cond CFF', 'condu CFF', 'conduc CFF', 'conducteur CFF'],
                'étalagiste': ['étalag', 'étalag', 'étal'],
                'confiseur': ['confis', 'confisr'],
                'employé': ['emp', 'empi', 'emplo', 'empl', 'employée'],
                'portier CFF': ['port CFF', 'portier CFF'],
                'portier': ['porte'],
                'voyagiste': ['voyagiste'],
                'gendarme': ['de gend', 'gendarm', 'gendarmerie', 'gend', 'sergent de gendarmerie', 'cap. de gend', 'capitaine gendarmerie'],
                'chauffeur': ['chauff', 'chauff'],
                'chauffeur CFF': ['chauff CFF', 'chauff CFF'],
                'céramiste': ['céram', 'cérami'],
                'brigadier de sûreté': ['brig', 'briga', 'brig de sûreté'],
                'assureur': ['assur', 'assuran', 'assureu'],
                'mécanicien': ['mécan', 'méca', 'mécano'],
                'mécanicien CFF': ['mécan CFF', 'méca CFF', 'mécano CFF'],
                'manœuvre': ['man', 'man', 'manœuv', 'manoeuvre'],
                'modiste': ['modis', 'mod'],
                'télégraphiste': ['télég', 'télégraphi', 'télégraphe'],
                'instituteur': ['instit', 'insituteu', 'insti', 'institutrice'],
                'représentant': ['repré', 'repr', 'représent'],
                'employé tramway': ['employédetrams', 'empl de tram', 'empl de trams'],
                "consul d'Italie": ["consul ditalie"],
                "vice-consul d'Italie": ["vice-consul ditalie"],
                'banquier': ['banq'],
                'dentiste': ['denti', 'dent'],
                'tabagiste': ['tabac', 'tabacs'],
                'étudiant': ['étud', 'étudia'],
                'tonnelier': ['tonnel'],
                'encaisseur': ['encaiss'],
                'cordonnier': ['cordonn', 'cordon', 'cordo'],
                'gérant': ['géran'],
                'ouvrier': ['ouvr'],
                'coiffeur': ['coiff', 'coiffeuse'],
                'tailleur': ['taill', 'tailleuse'],
                "inspecteur d'assurances": ["inspecteur d'assur"],
                'inspecteur CFF': ['inspect.CFF', 'inspect. CFF'],
                'rentier': ['rentière', 'renti', 'rent'],
                'tanneur': ['tann'],
                'vigneron': ['vign', 'vinger'],
                'commis': ['commi'],
                'commis CFF': ['com CFF', 'commis C.F.F.', 'com C.F.F.'],
                'pharmacien': ['pharmaa'],
                'couvreur': ['couvr'],
                'cuisinier': ['cuisin'],
                'restaurateur': ['restaur', 'g de rest'],
                'peintre': ['peint'],
                'horloger': ['horl', 'horloge'],
                'laitier': ['g laitier', 'laiterie'],
                'sommelier': ['sommel'],
                'violoncelliste': ['violoncel'],
                'sellier': ['sell'],
                'boulanger': ['boulan', 'boul'],
                'corsetière': ['corsetier'],
                'dactylographe': ['dactyl', 'dactylo'],
                'secrétaire': ['secrét'],
                'secrétaire CFF': ['secrét CFF'],
                'employé CFF': ['empi CFF', 'employ CFF'],
                'employé de commerce': ['emplo de commerce', 'empi de commerce'],
                'héliographe': ['hélio'],
                'médecin': ['méd', 'médec'],
                'géomètre': ['géo', 'géom'],
                'typographe': ['typo'],
                'menuisier': ['menu'],
                'consul de Belgique': ['consu de belgique'],
                'ingénieur': ['ingé', 'ing'],
                'domestique': ['domest'],
                'mouleur': ['moul'],
                'nettoyeur': ['netto', 'nett'],
                'artiste': ['art'],
                'publiciste': ['publi', 'publicité'],
                'concierge': ['concier', 'concierg'],
                'ramoneur': ['ramone'],
                'maréchal-ferrant': ['maréchal'],
                'pianiste': ['pian'],
                'chimiste': ['chim', 'chimi'],
                'livreur': ['livr', 'livraison'],
                'avocat': ['avoc'],
                'charcutier': ['charcut'],
                'épicier': ['épic'],
                'cafetier': ['cafet'],
                'lingère': ['ling', 'linger', 'linge'],
                'blanchisseuse': ['blanchis', 'blanchisseur', 'blanchiss'],
                'ébéniste': ['ében'],
                'fourreur': ['four', 'fourrures'],
                'relieur': ['reli', 'relieuse'],
                'teinturier': ['teint', 'tentur', 'teintures', 'teintureries'],
                'drogiste': ['drog', 'droguerie'],
                'commis postal': ['com. postal', 'comm. postal', 'commispostal'],
                'caissière': ['caisse', 'caissier'],
                'compositeur': ['compo', 'composit'],
                'charron': ['charr'],
                "agent d’affaires": ["agent d'aff"],
                'jounaliste': ['journal', 'journ'],
                'brodeuse': ['brod', 'brodeur'],
                'vendeur': ['vend', 'vendeuse'],
                'emballeur': ['emball', 'emballages'],
                'éditeur': ['éditeuse', 'édit', 'édition'],
                'jardinier': ['jardin', 'jardi'],
                'employé du gaz': ['empi du gaz', 'gaz'],
                'sténographe': ['sténo', 'steno'],
                "conseiller d'état": ["conseiller d'etat"],
                'attaché': ['attach', 'attachée'],
                'courtier': ['court', 'courtage'],
                'coutelier': ['couteaux', 'coutellerie'],
                'cocher': ['coch'],
                'employé des douanes': ['douanes', 'empi douanes', 'garde-front'],
                'administrateur': ['admin'],
                'fleuriste': ['fleurs', 'fleur'],
                'industriel': ['indust', 'indus'],
                'curé': ['cure', 'cur'],
                'imprimeur': ['impri', 'imprimerie'],
                'orfèvre': ['orfè', 'orf'],
                'oculiste': ['ocul'],
                'bijoutier': ['bijou', 'bijoux', 'bijoutière'],
                "chef d’institution": ["chef d'institut"],
                'papetier': ['papier', 'papeterie'],
                'religieux': ['religieuse'],
                'fonctionnaire': ['fonct', 'fonct postal', 'fonctionnaire postal'],
                'primeurs': ['prim', 'primeur'],
                'combustibles': ['combust'],
                'femme de chambre': ['f. de ch.', 'f de ch', 'f. de ch', 'f. de chambre'],
                'bottier': ['bottes', 'botte', 'bottière'],
                'sous-chef de gare': ['ss-chef de gare', 's.-chef de gare'],
                'employé postal': ['empi postal', 'employ postal', 'empl postal', 'employé de poste', 'employé des postes', 'emp. post'],
                'employé de banque': ['empi,de banque', 'emp. de banque'],
                'd. de mag': ['d de mag'],
                'professeur de piano et de chant': ['prof, depiano et chant'],
                'professeur de piano': ['prof, depiano', 'prof. de piano'],
                'professeur de musique': ['prof, musique'],
                'directeur du Crédit Suisse': ['dir Crédit Suisse'],
                'négociant en vins': ['négo. en vins', 'négoc. en vins'],
                'chef bureau CFF': ['chef bur. CFF'],
                'chef de train CFF': ['chef detrain CFF'],
                'masseur': ['masseuse', 'massouse'],
                'pension': ['pensio'],
                'ingénieur-professeur': ['ing. prof', 'ingé. prof'],
                'gouvernante': ['gouv'],
                'boucher': ['bouch'],
                'manœuvre CFF': ['man CFF'],
                'substitut du procureur génénéral': ['substitut duProcur. gén'],
                'facteur': ['fact'],
                'gypsier': ['gyps', 'gypse'],
                'faïences': ['faiences', 'faïence'],
                'commissionnaire': ['commissionnair'],
                'technicien': ['techni', 'techn'],
                'secrétaire à la direction de police': ['secrét. à ladir. de police'],
                'garde-malade': ['g.-mal.', 'g.-malade'],
                'employé de pharmacie': ['empi de phrmacie', 'employée de pharmacie', 'emp. de phar', 'emp. de pharmacie'],
                'tréfileur': ['tréfil', 'tréfileuse', 'tréfilage'],
                'professeur de peinture': ['prof. de peinture'],
                'directeur de pensionnat': ['dir. de pensionnat'],
                'droguiste': ['drog.', 'drogue', 'droguerie', 'droguerie en gros'],
                'vitrier': ['vitre', 'vit.', 'vitrerie'],
                'vulcanisateur': ['vulcan', 'vulcanisation', 'vulcanisatrice'],
                'chef de bureau postal': ['chef de bureaupostal'],
                'sculpteur': ['sculpt', 'sculpteuse', 'sculpterie'],
                'bouclier': ['boucle', 'boucl.'],
                'appareilleur': ['appreill'],
                'voyageur': ['voyageuse', 'voyag.'],
                'contrôleur': ['controleur', 'contrôl', 'contrôle', 'controle'],
                'plieur': ['plieuse', 'pli', 'pliage'],
                'charretier': ['charrette', 'charretière'],
                'inspecteur des bâtiments': ['inspect. des bâtiments'],
                'musicien': ['musique', 'musicien'],
                'batelier': ['batelière'],
                'ouvrier CFF': ['ouvrière CFF', 'ouvr. CFF'],
                'postillon': ['postill.'],
                'professeur de dessin': ['prof. dessin'],
                'briquetier': ['briques'],
                'pierriste': ['pierres', 'pierre'],
                'magasinier': ['magas.', 'magasin'],
                'charpentier': ['charpente'],
                'commissionnaire': ['commission'],
                'dessinateur': ['dessin'],
                'brasseur': ['brasseuse'],
                'électricien CFF': ['électr. CFF'],
                'constructeur de bateaux': ['const, de bateaux'],
                'machiniste': ['machine'],
                'lithographe': ['lithogr.', 'lith'],
                'monteur': ['monteuse', 'montage'],
                'opticien': ['optique', 'opticienne'],
                "huissier du Conseil d’Etat": ["huissier duConseil d’Etat"],
                'désinfecteur': ['désinfection', 'désinfect'],
                'pâtissier': ['pâtiss'],
                'infirmier': ['infirmière', 'infirm'],
                'pasteur': ['past'],
                'liftier': ['lift'],
                'employé de bureau': ['empl de bureau', 'empi bureau', 'employée de bureau'],
                "employé au consulat d'Italie": [],
                'consul du Pérou': ['Consul du Pérou'],
                'employé consulat': ['empi consulat']
}

# %%
artisanat_cat = [
    "charpentier",
    "céramiste",
    "cordonnier",
    "couturier",
    "ébéniste",
    "maçon",
    "menuisier",
    "serrurier",
    "tailleur",
    "tapissier",
    "tonnelier",
    "maréchal-ferrant",
    "forgeron",
    "encaisseur",
    "tanneur",
    "peintre",
    'horloger',
    'sellier',
    'corsetière',
    'ramoneur',
    'relieur',
    'teinturier',
    'fourreur',
    'charron',
    "brodeuse",
    "jardinier",
    "coutelier",
    "fleuriste",
    "désinfecteur",
    "pâtissier",
    "cafetier",
    "gypsier",
    "faïences",
    "brasseur",
    "orfèvre",
    "bijoutier",
    "bottier",
    "vitrier",
    "tréfileur",
    "bouclier",
]

administration_politique_cat = [
    "administrateur",
    "chef d’institution",
    "consul d'Italie",
    "consul de Belgique",
    "directeur du Crédit Suisse",
    "directeur de pensionnat",
    "gérant",
    "inspecteur des bâtiments",
    "secrétaire à la direction de police",
    "vice-consul d'Italie",
    "conseiller d'état",
    "substitut du procureur général",
    "chef de bureau postal",
    "sous-chef de gare",
    "employé de bureau",
    "employé au consulat d'Italie",
    'consul du Pérou',
    'employé consulat',
    "directeur",
    "employé",
    "attaché",
    "employé des douanes",
    "avocat",
    "fonctionnaire",
    "substitut du procueur génénéral",
    "huissier du Conseil d’Etat",
    ]


decideurs_cat = [
    "administrateur",
    "chef d’institution",
    "consul d'Italie",
    "consul de Belgique",
    "directeur du Crédit Suisse",
    "directeur de pensionnat",
    "gérant",
    "vice-consul d'italie",
    "conseiller d'état",
    'consul du Pérou',
    "directeur",
    "industriel",
    "substitut du procueur génénéral"
]

elites = [
    "consul d'Italie",
    "consul de Belgique",
    "directeur du Crédit Suisse",
    "vice-consul d'italie",
    "conseiller d'état",
    'consul du Pérou',
    "substitut du procueur génénéral"
]

commerce_cat = [
    "caissière",
    "commerçant",
    "courtier",
    "droguiste",
    "étalagiste",
    "négociant en vins",
    "représentant",
    "vendeur",
    "boulanger",
    "boucher",
    "magasinier",
    "charcutier",
    "épicier",
    "confiseur",
    "modiste",
    "tabagiste",
    "pâtissier",
    "primeurs",
    "cafetier",
    "pharmacien",
    "employé de pharmacie",
    "d. de mag",
    "laitier",
    "restaurateur",
]

commerces_essentiels = [
    "droguiste",
    "boulanger",
    "boucher",
    "charcutier",
    "épicier",
    "confiseur",
    "tabagiste",
    "pharmacien",
    "employé de pharmacie",
]

industrie_cat = [
    "électricien",
    "électricien CFF",
    "ingénieur",
    "machiniste",
    "monteur",
    "technicien",
    "chimiste",
    "ingénieur-professeur",
    "architecte",
    "mécanicien CFF",
    "mécanicien",
    "manœuvre",
    "ouvrier",
    "commis",
    "couvreur",
    "peintre",
    "typographe",
    "géomètre",
    "charron",
    "imprimeur",
    "sténographe",
    "emballeur",
    "brasseur",
    "constructeur de bateaux",
    "industriel",
    "vulcanisateur",
    "briquetier",
    "pierriste",
    "plieur",
    "charretier",
    "papetier",
    "combustibles",
    "appareilleur",
    "batelier",
    "mouleur",

]

transport_cat = [
    "chauffeur",
    "chauffeur CFF",
    "conducteur CFF",
    "facteur",
    "livreur",
    "postillon",
    "voyageur",
    "contrôleur",
    "commis CFF",
    "sous-chef de gare",
    "chef de train CFF",
    "mécanicien CFF",
    "mécanicien",
    "conducteur",
    "employé tramway",
    "inspecteur CFF",
    "cocher",
    "maréchal-ferrant",
    "manœuvre CFF",
    "chef bureau CFF",
]

sante_cat = [
    "médecin",
    "dentiste",
    "infirmier",
    "masseur",
    "garde-malade",
    "pharmacien",
    "opticien",
    "employé de pharmacie",
    "oculiste"
]

enseignement_cat = [
    "professeur de piano",
    "professeur de musique",
    "professeur de peinture",
    "professeur de dessin",
    "instituteur",
    "gouvernante",
    "professeur de piano et de chant",
    "ingénieur-professeur",
    "professeur",
    "étudiant",
]

arts_cat = [
    "artiste",
    "compositeur",
    "musicien",
    "pianiste",
    "violoncelliste",
    "sculpteur",
    "dessinateur",
    "publiciste",
    'journaliste',
    "écrivain",
    "lithographe",
    "professeur de piano",
    "professeur de musique",
    "professeur de peinture",
    "professeur de dessin",
    "professeur de piano et de chant",
    "éditeur",
    "peintre",
]

hotellerie_cat = [
    "cuisinier",
    "sommelier",
    "femme de chambre",
    "concierge",
    "lingère",
    "blanchisseuse",
    "domestique",
    "nettoyeur",
    "portier",
    "liftier",
    "pension",
]

securite_cat = [
    "policier",
    "gendarme",
    "brigadier de sûreté",
    "gardien de prison",
    "huissier",
]

agriculture_cat = [
    "agriculteur",
    "vigneron",
    "laitier",
]

banque_assurances_services_cat = [
    "banquier",
    "comptable",
    "assureur",
    "employé de banque",
    "directeur du crédit suisse",
    "inspecteur d'assurances",
    "négociant",
    "commis",
    'dacytlographe',
    'secrétaire',
    "employé de commerce",
    "typographe",
    "dactylographe",
    "agent d’affaires",
    "éditeur",
    "jounaliste",
    "sténographe",
    "commissionnaire",
]

cff_cat = [
    "commis CFF",
    "chef de train CFF",
    "sous-chef de gare",
    "portier CFF",
    "électricien CFF",
    "conducteur CFF",
    "mécanicien CFF",
    "inspecteur CFF",
    'secrétaire CFF',
    "employé CFF",
    "chef bureau CFF",
    'manœuvre CFF',
    "ouvrier CFF",
]

poste_cat = [
    "commis postal",
    "chef de bureau postal",
    "télégraphiste",
    "héliographe",
    "employé postal",
]

gaz_cat = [
    "employé du gaz"
]

religion_cat = [
    "évangéliste",
    "pasteur",
    "curé",
    "religieux",
]

douanes_cat = [
    "employé des douanes"
]

luxe_cat = [
    "tailleur",
    'corsetière',
    'horloger',
    'bijoutier',
    'orfèvre',
    'couturier',
    'fleuriste',
    "pâtissier",
    "confiseur",
    'fourreur',
]

metiers_qualifies = [
    "ingénieur",
    "chimiste",
    "ingénieur-professeur",
    "architecte",
    "géomètre",
]

autres_cat = [
    'rentier',
    'veuve',
    'ménagère'
]

# %%
all_cat_for_export = {
    'Artisanat': artisanat_cat,
    'Administration et Politique': administration_politique_cat,
    'Postes à responsabilités': decideurs_cat,
    'Commerces': commerce_cat,
    'Commerces Essentiels': commerces_essentiels,
    'Élites': elites,
    'Transports': transport_cat,
    'Santé': sante_cat,
    'Enseignement': enseignement_cat,
    'Arts': arts_cat,
    'Hotellerie': hotellerie_cat,
    'Securité': securite_cat,
    'Agriculture': agriculture_cat,
    'Banques, Assurances et Services': banque_assurances_services_cat,
    'CFF': cff_cat,
    'Poste et communications': poste_cat,
    'Industrie': industrie_cat,
    'Religion et spiritualité': religion_cat,
    'Douanes': douanes_cat,
    'Luxe': luxe_cat,
    'Métiers Qualifiés': metiers_qualifies,
    'Autres': autres_cat,
}

# %%
all_cat = set(artisanat_cat).union(administration_politique_cat).union(decideurs_cat).union(commerce_cat).union(transport_cat).union(sante_cat).union(enseignement_cat).union(arts_cat).union(hotellerie_cat).union(securite_cat).union(agriculture_cat).union(banque_assurances_services_cat).union(cff_cat).union(poste_cat).union(gaz_cat).union(industrie_cat).union(religion_cat).union(douanes_cat).union(autres_cat)

# %%
i = 0
for f in JOB_CAT_ABRV.keys():
    if f not in all_cat:
        print("missing", f)
        i += 1

print("i = ", i)
# Out:
# missing chef
# missing voyagiste
# missing coiffeur
# missing drogiste
# missing substitut du procureur génénéral
# i =  5

# %%
JOB_CAT_ABRV.keys()
# Out:
# dict_keys(['chef', 'policier', 'électricien', 'architecte', 'professeur', 'couturier', 'tapissier', 'agriculteur', 'directeur', 'ménagère', 'serrurier', 'commerçant', 'maçon', 'évangéliste', 'comptable', 'veuve', 'négociant', 'conducteur CFF', 'étalagiste', 'confiseur', 'employé', 'portier CFF', 'portier', 'voyagiste', 'gendarme', 'chauffeur', 'chauffeur CFF', 'céramiste', 'brigadier de sûreté', 'assureur', 'mécanicien', 'mécanicien CFF', 'manœuvre', 'modiste', 'télégraphiste', 'instituteur', 'représentant', 'employé tramway', "consul d'Italie", "vice-consul d'Italie", 'banquier', 'dentiste', 'tabagiste', 'étudiant', 'tonnelier', 'encaisseur', 'cordonnier', 'gérant', 'ouvrier', 'coiffeur', 'tailleur', "inspecteur d'assurances", 'inspecteur CFF', 'rentier', 'tanneur', 'vigneron', 'commis', 'commis CFF', 'pharmacien', 'couvreur', 'cuisinier', 'restaurateur', 'peintre', 'horloger', 'laitier', 'sommelier', 'violoncelliste', 'sellier', 'boulanger', 'corsetière', 'dactylographe', 'secrétaire', 'secrétaire CFF', 'employé CFF', 'employé de commerce', 'héliographe', 'médecin', 'géomètre', 'typographe', 'menuisier', 'consul de Belgique', 'ingénieur', 'domestique', 'mouleur', 'nettoyeur', 'artiste', 'publiciste', 'concierge', 'ramoneur', 'maréchal-ferrant', 'pianiste', 'chimiste', 'livreur', 'avocat', 'charcutier', 'épicier', 'cafetier', 'lingère', 'blanchisseuse', 'ébéniste', 'fourreur', 'relieur', 'teinturier', 'drogiste', 'commis postal', 'caissière', 'compositeur', 'charron', 'agent d’affaires', 'jounaliste', 'brodeuse', 'vendeur', 'emballeur', 'éditeur', 'jardinier', 'employé du gaz', 'sténographe', "conseiller d'état", 'attaché', 'courtier', 'coutelier', 'cocher', 'employé des douanes', 'administrateur', 'fleuriste', 'industriel', 'curé', 'imprimeur', 'orfèvre', 'oculiste', 'bijoutier', 'chef d’institution', 'papetier', 'religieux', 'fonctionnaire', 'primeurs', 'combustibles', 'femme de chambre', 'bottier', 'sous-chef de gare', 'employé postal', 'employé de banque', 'd. de mag', 'professeur de piano et de chant', 'professeur de piano', 'professeur de musique', 'directeur du Crédit Suisse', 'négociant en vins', 'chef bureau CFF', 'chef de train CFF', 'masseur', 'pension', 'ingénieur-professeur', 'gouvernante', 'boucher', 'manœuvre CFF', 'substitut du procureur génénéral', 'facteur', 'gypsier', 'faïences', 'commissionnaire', 'technicien', 'secrétaire à la direction de police', 'garde-malade', 'employé de pharmacie', 'tréfileur', 'professeur de peinture', 'directeur de pensionnat', 'droguiste', 'vitrier', 'vulcanisateur', 'chef de bureau postal', 'sculpteur', 'bouclier', 'appareilleur', 'voyageur', 'contrôleur', 'plieur', 'charretier', 'inspecteur des bâtiments', 'musicien', 'batelier', 'ouvrier CFF', 'postillon', 'professeur de dessin', 'briquetier', 'pierriste', 'magasinier', 'charpentier', 'dessinateur', 'brasseur', 'électricien CFF', 'constructeur de bateaux', 'machiniste', 'lithographe', 'monteur', 'opticien', 'huissier du Conseil d’Etat', 'désinfecteur', 'pâtissier', 'infirmier', 'pasteur', 'liftier', 'employé de bureau', "employé au consulat d'Italie", 'consul du Pérou', 'employé consulat'])

# %%
i = 0
for f in all_cat:
    if f not in JOB_CAT_ABRV.keys():
        print("missing", f)
        i += 1

print("i = ", i)
# Out:
# missing directeur du crédit suisse
# missing gardien de prison
# missing vice-consul d'italie
# missing journaliste
# missing substitut du procueur génénéral
# missing forgeron
# missing dacytlographe
# missing huissier
# missing écrivain
# missing conducteur
# missing substitut du procureur général
# i =  11

# %%
import json
with open('macro-classes.json', 'w', encoding='utf-8') as f:
    json.dump(all_cat_for_export, f, ensure_ascii=False, indent=4)
